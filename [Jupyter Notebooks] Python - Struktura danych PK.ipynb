# %% [markdown]
# <font size = "+3">Python struktura danych </font>
#
# W tym notatniku dowiemy się o zbiorach danych występujących w języku Python.

# %% [markdown]
# ## Zbiory danych

# %% [markdown]
# Lista ###

# %%
# Utwórz heterogeniczną listę (zawierającą różne typy danych) o nazwie "list1"
list1 = ['Apple',25,-89,True,3.56]

# %%
# Wydrukuj listę
print(list1)
# Out:
# ['Apple', 25, -89, True, 3.56]

# %%
# Wyciągnij trzecią wartość z listy
list1[2]
# Out:
# -89

# %%
# Utwórz kolejną listę o nazwie "fruits" i stwórz w niej 4 elementy
fruits = ['mango', 'apple', 'orange', 'banana']

# %%
# Dodaj do listy nowy element "cherry"
# Metoda append() pozwala dodać element na koniec listy
fruits.append('cherry')

# %%
# Wyświetl wszystkie pozycje z listy
print(fruits)
# Out:
# ['mango', 'apple', 'orange', 'banana', 'cherry']

# %%
# Zmień czwarty element na "pineapple"
fruits[3]='pineapple'
print(fruits)
# Out:
# ['mango', 'apple', 'orange', 'pineapple', 'cherry']

# %%
# Wstaw element "orange" pomarańczowy na czwarty indeks
fruits.insert(4,'orange')

# %%
print(fruits)
# Out:
# ['mango', 'apple', 'orange', 'pineapple', 'orange', 'cherry']

# %% [markdown]
# Spójrz, element "orange" występuje dwa razy na powyższej liście

# %%
# Usuń element "apple" z listy
fruits.pop(1)
# Out:
# 'apple'

# %%
print(fruits)
# Out:
# ['mango', 'orange', 'pineapple', 'orange', 'cherry']

# %% [markdown]
# Element "apple" został usunięte z listy

# %%
# Sortuj elementy w kolejności rosnącej
fruits.sort()

# %%
fruits
# Out:
# ['cherry', 'mango', 'orange', 'orange', 'pineapple']

# %%
# Sortuj elementy w kolejności malejącej
fruits.sort(reverse=True)

# %%
fruits
# Out:
# ['pineapple', 'orange', 'orange', 'mango', 'cherry']

# %% [markdown]
# ### Krotki (Tuple)

# %%
# Utwórz krotkę o nazwie „friends” i dodaj do niej 4 elementy
friends = ('monica','chandler','pheobe','rachel')

# %%
friends
# Out:
# ('monica', 'chandler', 'pheobe', 'rachel')

# %%
# Uzyskaj dostęp do ostatniego elementu
friends[3]
# Out:
# 'rachel'

# %%
# Uzyskaj dostęp do ostatniego elementu za pomocą indeksowania ujemnego
friends[-1]
# Out:
# 'rachel'

# %%
# Uzyskaj dostęp do grupy elementów za pomocą negatywnego indeksowania
friends[-3:-1]
# Out:
# ('chandler', 'pheobe')

# %% [markdown]
# Powyższa krotka zwraca elementy od indeksu -3 (łącznie) do indeksu -1 (rozłącznie)

# %%
# Konwertuj krotkę na listę
y = list(friends)

# %%
y
# Out:
# ['monica', 'chandler', 'pheobe', 'rachel']

# %%
y.append('ross')

# %%
y
# Out:
# ['monica', 'chandler', 'pheobe', 'rachel', 'ross']

# %%
# Dodaj krotkę do krotki
y = ('monica',)
friends = friends + y

# %%
friends
# Out:
# ('monica', 'chandler', 'pheobe', 'rachel', 'monica')

# %%
# Usuń element z krotki. Najpierw przekonwertuj krotkę na listę
x = list(friends)

# %%
x.remove('joey')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 x.remove('joey')
#
# ValueError: list.remove(x): x not in list

# %%
x
# Out:
# ['monica', 'chandler', 'pheobe', 'rachel', 'monica']

# %%
# Usuń całą krotkę
del friends

# %%
friends
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 friends
#
# NameError: name 'friends' is not defined

# %% [markdown]
# Program zwróci błąd, ponieważ krotka już nie istnieje

# %% [markdown]
# ### Zbiory

# %%
# Utwórz zbiór o nazwie "flowers" składający się z 3 elementów
flowers = {'lily','rose','lotus'}

# %%
flowers
# Out:
# {'lily', 'lotus', 'rose'}

# %%
# Dodaj element "jasmine" do zbioru "flowers"
flowers.add('jasmine')

# %%
# Policz liczbę elementów w zbiorze "flowers"
len(flowers)
# Out:
# 4

# %%
# Dodaj elementy za zbioru "other" do zbioru "flowers"
other = {'tulip'}
flowers.update(other)

# %%
flowers
# Out:
# {'jasmine', 'lily', 'lotus', 'rose', 'tulip'}

# %%
# Usuń "jasmine" ze zbioru "flowers"
flowers.remove('jasmine')

# %%
flowers
# Out:
# {'lily', 'lotus', 'rose', 'tulip'}

# %% [markdown]
# Element "jasmine" został usunięty ze zbioru

# %%
# Ponowne usunięcie elementu "jasmine" za pomocą metody remove() zwróci błąd
flowers.remove('jasmine')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[40], line 2
#       1 # Ponowne usunięcie elementu "jasmine" za pomocą metody remove() zwróci błąd
# ----> 2 flowers.remove('jasmine')
#
# KeyError: 'jasmine'

# %%
# Spróbujmy usunąć "jasmine" za pomocą discard()
flowers.discard('jasmine')

# %% [markdown]
# Jeśli w danym zbiorze wskazany przez użytkownika element do usunięcia nie istnieje, metoda remove() zwróci błąd, w przeciwieństwie do metoda discard()

# %%
# Metoda pop() używamy do usunięcia ostatniego elementu ze zbioru
x = flowers.pop()

# %% [markdown]
# Uwaga! Zbiory nie są uporządkowane, więc wywołując metodę pop() nie wiemy, który element zostanie usunięty

# %%
print(x)
print(flowers)
# Out:
# lotus
# {'lily', 'tulip', 'rose'}

# %%
# Wyczyść zbiór "flowers"
flowers.clear()

# %%
flowers
# Out:
# set()

# %% [markdown]
# ### Słownik

# %%
# Utwórz słownik "calendar" (pierwsze pięć miesięcy)
calendar = {1:'Jan',2:'Feb',3:'Mar',4:'Apr',5:'May'}

# %%
calendar
# Out:
# {1: 'Jan', 2: 'Feb', 3: 'Mar', 4: 'Apr', 5: 'May'}

# %%
# Dostęp do elementu słownika za pomocą nazwy kluczowej
z = calendar[3]

# %%
z
# Out:
# 'Mar'

# %% [markdown]
# # Wyświetl wszystkie klucze w słowniku
# calendar.keys ()

# %%
# Zmień konkretny element, odnosząc się do jego klucza
calendar[4]='April'

# %%
calendar
# Out:
# {1: 'Jan', 2: 'Feb', 3: 'Mar', 4: 'April', 5: 'May'}

# %%
# Zaktualizuj kalendarz o jeszcze jeden element
calendar.update({6:'June'})

# %%
calendar
# Out:
# {1: 'Jan', 2: 'Feb', 3: 'Mar', 4: 'April', 5: 'May', 6: 'June'}

# %%
# Utwórz kopię słownika
new = calendar.copy()

# %%
new
# Out:
# {1: 'Jan', 2: 'Feb', 3: 'Mar', 4: 'April', 5: 'May', 6: 'June'}

# %% [markdown]
# ### Program do rezerwacji filmów
#
# W tym programie będziemy używać
# * struktur danych takich jak słownik, lista
# * Instrukcji warunkowych if-else
# * Pętli while
# * Rzutowanie (konwersja) typów

# %%
# Utwórz słownik filmów. Niech kluczem będzie nazwa filmu, a parą wartości dwie liczby:
# kryteria wiekowe oraz liczba dostępnych biletów
movies = {
    "Finding Nemo": [5, 2],
    "Moana": [6, 3],
    "Batman": [18, 5],
    "The Lion King": [10, 4]
}

# Utwórz pętlę, która będzie działać w nieskończoność
while True:
    # Pobierz tytuł filmu od użytkownika, usuń spacje z początku i końca
    # a następnie zamień frazę na format tytułowy (pierwsza litera każdego słowa jest wielka)
    title = input("Podaj tytuł filmu (lub 'koniec' aby zakończyć): ").strip().title()

    if title == "Koniec":
        print("Zakończono.")
        break

    # Sprawdź, czy film istnieje w słowniku
    if title in movies:
        # Zapytaj użytkownika o wiek
        try:
            age = int(input("Podaj swój wiek: ").strip())
        except ValueError:
            print("Błąd: wiek musi być liczbą.")
            continue

        # Pobierz wymagany wiek i liczbę biletów
        required_age = movies[title][0]
        tickets = movies[title][1]

        # Sprawdź użytkownika pod kątem kwalifikowalności
        if age >= required_age:
            # Sprawdź dostępność miejsc
            if tickets > 0:
                movies[title][1] -= 1
                print(f"Bilet kupiony. Pozostało biletów na '{title}': {movies[title][1]}")
            else:
                print(f"Brak biletów na film '{title}'.")
        else:
            print(f"Nie spełniasz kryterium wiekowego. Film '{title}' jest od {required_age} lat.")
    else:
        print("Nie ma takiego filmu w repertuarze.")
        print("Dostępne filmy:")
        for m in movies:
            print("-", m)
# Out:
# Podaj tytuł filmu (lub 'koniec' aby zakończyć):  titanic
# Nie ma takiego filmu w repertuarze.
# Dostępne filmy:
# - Finding Nemo
# - Moana
# - Batman
# - The Lion King
# Podaj tytuł filmu (lub 'koniec' aby zakończyć):  batman
# Podaj swój wiek:  23
# Bilet kupiony. Pozostało biletów na 'Batman': 4
# Podaj tytuł filmu (lub 'koniec' aby zakończyć):  koniec
# Zakończono.

# %% [markdown]
# ## Moduł random

# %%
# Moduł do losowania liczb
import random

# %%
# randrange() - Ta metoda zwraca losową liczbę z określonego zakresu
# Składnia: random.randrange(start, stop, krok)

# Zwraca liczbę między 10 (łącznie) a 26 (rozłącznie). Krok wynosi 1, więc zwróci wszystkie liczby z tego zakresu. Jeśli krok jest większy niż 1, zwróci tylko liczby, które są wielokrotnościami tego kroku.
random.randrange(10,26,1)
# Out:
# 19

# %%
# randint() - Ta metoda zwraca liczbę całkowitą z określonego zakresu
# Składnia: random.randint(start, stop)

# Zwraca liczbę od 50 do 100 (obie wartości są włączone)
random.randint(50,100)
# Out:
# 76

# %%
# choice() - Ta metoda zwraca losowy element z określonej sekwencji
# Składnia: random.choice(sekwencja)

x = ['Python','Program','Language']
random.choice(x)
# Out:
# 'Python'
